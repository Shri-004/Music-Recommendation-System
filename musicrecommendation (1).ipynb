# %%
import pandas as pd
import numpy as np
import Recommenders as Recommenders
import matplotlib.pyplot as plt

# %%
song_df_1 = pd.read_csv("triplets_file.csv")
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 = pd.read_csv("song_data.csv")
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
# combine both data
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
print(len(song_df_1), len(song_df_2))
# Out:
# 2000000 1000000

# %%
len(song_df)
# Out:
# 2000000

# %%
# creating new feature combining title and artist name
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %%
# taking top 10k samples for quick results
song_df = song_df.head(10000)

# %%
# cummulative sum of listen count of the songs
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                     song  listen_count
# 0               #40 - DAVE MATTHEWS BAND             1
# 1                    & Down - Boys Noize             4
# 2            '97 Bonnie & Clyde - Eminem             2
# 3          'Round Midnight - Miles Davis             3
# 4  'Till I Collapse - Eminem / Nate Dogg             6

# %%
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count  \
# 3660                           Sehr kosmisch - Harmonia            45
# 4678                                       Undo - Björk            32
# 5105                     You're The One - Dwight Yoakam            32
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...            28
# 3655                              Secrets - OneRepublic            28
# ...                                                 ...           ...
# 5139                              high fives - Four Tet             1
# 5140                       in white rooms - Booka Shade             1
# 5143             paranoid android - Christopher O'Riley             1
# 5149            ¿Lo Ves? [Piano Y Voz] - Alejandro Sanz             1
# 5150                              Época - Gotan Project             1
#
#       percentage
# 3660        0.45
# 4678        0.32
# 5105        0.32
# 1071        0.28
# 3655        0.28
# ...          ...
# 5139        0.01
# 5140        0.01
# 5143        0.01
# 5149        0.01
# 5150        0.01
#
# [5151 rows x 3 columns]

# %%
pr = Recommenders.popularity_recommender_py()

# %%
pr.create(song_df, 'user_id', 'song')

# %%
# display the top 10 popular songs
new_recomdation_2 = pr.recommend(song_df['user_id'][5])
new_recomdation_2
# Out:
#                                        user_id  \
# 3660  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4678  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5105  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1071  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3655  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4378  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4712  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3476  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1387  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1862  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 3660                           Sehr kosmisch - Harmonia     45   1.0
# 4678                                       Undo - Björk     32   2.0
# 5105                     You're The One - Dwight Yoakam     32   3.0
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...     28   4.0
# 3655                              Secrets - OneRepublic     28   5.0
# 4378                           The Scientist - Coldplay     27   6.0
# 4712                       Use Somebody - Kings Of Leon     27   7.0
# 3476                            Revelry - Kings Of Leon     26   8.0
# 1387                     Fireflies - Charttraxx Karaoke     24   9.0
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...     23  10.0

# %%
pr.recommend(song_df['user_id'][13])
# Out:
#                                        user_id  \
# 3660  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4678  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5105  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1071  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3655  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4378  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4712  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3476  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1387  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1862  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 3660                           Sehr kosmisch - Harmonia     45   1.0
# 4678                                       Undo - Björk     32   2.0
# 5105                     You're The One - Dwight Yoakam     32   3.0
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...     28   4.0
# 3655                              Secrets - OneRepublic     28   5.0
# 4378                           The Scientist - Coldplay     27   6.0
# 4712                       Use Somebody - Kings Of Leon     27   7.0
# 3476                            Revelry - Kings Of Leon     26   8.0
# 1387                     Fireflies - Charttraxx Karaoke     24   9.0
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...     23  10.0

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')

# %%
user_items = ir.get_user_items(song_df['user_id'][5])

# %%
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# The Cove - Jack Johnson
# Entre Dos Aguas - Paco De Lucia
# Stronger - Kanye West
# Constellations - Jack Johnson
# Learn To Fly - Foo Fighters
# Apuesta Por El Rock 'N' Roll - Héroes del Silencio
# Paper Gangsta - Lady GaGa
# Stacked Actors - Foo Fighters
# Sehr kosmisch - Harmonia
# Heaven's gonna burn your eyes - Thievery Corporation feat. Emiliana Torrini
# Let It Be Sung - Jack Johnson / Matt Costa / Zach Gill / Dan Lebowitz / Steve Adams
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
# Love Shack - The B-52's
# Clarity - John Mayer
# I?'m A Steady Rollin? Man - Robert Johnson
# The Old Saloon - The Lonely Island
# Behind The Sea [Live In Chicago] - Panic At The Disco
# Champion - Kanye West
# Breakout - Foo Fighters
# Ragged Wood - Fleet Foxes
# Mykonos - Fleet Foxes
# Country Road - Jack Johnson / Paula Fuga
# Oh No - Andrew Bird
# Love Song For No One - John Mayer
# Jewels And Gold - Angus & Julia Stone
# Warning - Incubus
# 83 - John Mayer
# Neon - John Mayer
# The Middle - Jimmy Eat World
# High and dry - Jorge Drexler
# All That We Perceive - Thievery Corporation
# The Christmas Song  (LP Version) - King Curtis
# Our Swords (Soundtrack Version) - Band Of Horses
# Are You In? - Incubus
# Drive - Incubus
# Generator - Foo Fighters
# Come Back To Bed - John Mayer
# He Doesn't Know Why - Fleet Foxes
# Trani - Kings Of Leon
# Bigger Isn't Better - The String Cheese Incident
# Sun Giant - Fleet Foxes
# City Love - John Mayer
# Right Back - Sublime
# Moonshine - Jack Johnson
# Holes To Heaven - Jack Johnson

# %%
# give song recommendation for that user
new_recomdation_1=ir.recommend(song_df['user_id'][5])
new_recomdation_1
# Out:
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 5151
# Non zero values in cooccurence_matrix :6844
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                         song     score  rank
# 0                 Oliver James - Fleet Foxes  0.043076     1
# 1                 Quiet Houses - Fleet Foxes  0.043076     2
# 2               Your Protector - Fleet Foxes  0.043076     3
# 3  Tiger Mountain Peasant Song - Fleet Foxes  0.043076     4
# 4                 Sun It Rises - Fleet Foxes  0.043076     5
# 5                        The End - Pearl Jam  0.037531     6
# 6                St. Elsewhere - Dave Grusin  0.037531     7
# 7                       Misled - Céline Dion  0.037531     8
# 8                    Oil And Water - Incubus  0.037531     9
# 9                  Meadowlarks - Fleet Foxes  0.037531    10

# %%
ir.recommend(song_df['user_id'][100])
# Out:
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 5151
# Non zero values in cooccurence_matrix :11051
#                                     user_id  \
# 0  e006b1a48f466bf59feefed32bec6494495a4436
# 1  e006b1a48f466bf59feefed32bec6494495a4436
# 2  e006b1a48f466bf59feefed32bec6494495a4436
# 3  e006b1a48f466bf59feefed32bec6494495a4436
# 4  e006b1a48f466bf59feefed32bec6494495a4436
# 5  e006b1a48f466bf59feefed32bec6494495a4436
# 6  e006b1a48f466bf59feefed32bec6494495a4436
# 7  e006b1a48f466bf59feefed32bec6494495a4436
# 8  e006b1a48f466bf59feefed32bec6494495a4436
# 9  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                 song     score  rank
# 0  Lucky (Album Version) - Jason Mraz & Colbie Ca...  0.102113     1
# 1                   Somebody To Love - Justin Bieber  0.093648     2
# 2             Just Dance - Lady GaGa / Colby O'Donis  0.093492     3
# 3                              Alejandro - Lady GaGa  0.090891     4
# 4                    Heartbreak Warfare - John Mayer  0.090690     5
# 5                          Love Story - Taylor Swift  0.088481     6
# 6                           The Scientist - Coldplay  0.085540     7
# 7  Bleed It Out [Live At Milton Keynes] - Linkin ...  0.079296     8
# 8                              Bulletproof - La Roux  0.077164     9
# 9      The Only Exception (Album Version) - Paramore  0.076146    10

# %%
import seaborn as sns
from scipy.sparse import csr_matrix
from knn_recommender import Recommender
from scipy.sparse import csr_matrix
# Out:
# c:\Users\Mahesh\AppData\Local\Programs\Python\Python310\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# Collaborative Filtering

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#Read userid-songid-listen_count
song_info = pd.read_csv('triplets_file.csv')
#song_info.columns = ['user_id', 'song_id', 'listen_count']

#Read song  metadata
song_actual =  pd.read_csv('song_data.csv')
song_actual.drop_duplicates(['song_id'], inplace=True)

#Merge the two dataframes above to create input dataframe for recommender systems
songs = pd.merge(song_info, song_actual, on="song_id", how="left")

# %%
songs.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
songs.to_csv('songs.csv', index=False)

# %%
df_songs = pd.read_csv('songs.csv')

# %% [markdown]
# Performing Exploratatory data analysis

# %%
df_songs.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
#Get total observations
print(f"There are {df_songs.shape[0]} observations in the dataset")
# Out:
# There are 2000000 observations in the dataset

# %%
#Unique songs
unique_songs = df_songs['title'].unique().shape[0]
print(f"There are {unique_songs} unique songs in the dataset")
# Out:
# There are 9567 unique songs in the dataset

# %%
#Unique artists
unique_artists = df_songs['artist_name'].unique().shape[0]
print(f"There are {unique_artists} unique artists in the dataset")
# Out:
# There are 3375 unique artists in the dataset

# %%
#Unique users
unique_users = df_songs['user_id'].unique().shape[0]
print(f"There are {unique_users} unique users in the dataset")
# Out:
# There are 76353 unique users in the dataset

# %%
#count how many rows we have by song, we show only the ten more popular songs 
ten_pop_songs = df_songs.groupby('title')['listen_count'].count().reset_index().sort_values(['listen_count', 'title'], ascending = [0,1])
ten_pop_songs['percentage']  = round(ten_pop_songs['listen_count'].div(ten_pop_songs['listen_count'].sum())*100, 2)

# %%
ten_pop_songs = ten_pop_songs[:10]
ten_pop_songs
# Out:
#                                                   title  listen_count  \
# 6836                                      Sehr kosmisch          8277
# 8725                                               Undo          7032
# 1964                     Dog Days Are Over (Radio Edit)          6949
# 9496                                     You're The One          6729
# 6498                                            Revelry          6145
# 6825                                            Secrets          5841
# 3437  Horn Concerto No. 4 in E flat K495: II. Romanc...          5385
# 2595                                          Fireflies          4795
# 3322                                   Hey_ Soul Sister          4758
# 8494                                           Tive Sim          4548
#
#       percentage
# 6836        0.41
# 8725        0.35
# 1964        0.35
# 9496        0.34
# 6498        0.31
# 6825        0.29
# 3437        0.27
# 2595        0.24
# 3322        0.24
# 8494        0.23

# %%
labels = ten_pop_songs['title'].tolist()
counts = ten_pop_songs['listen_count'].tolist()

# %%
plt.figure()
sns.barplot(x=counts, y=labels, palette='Set3')
sns.despine(left=True, bottom=True)

# %%
#count how many rows we have by artist name, we show only the ten more popular artist 
ten_pop_artists  = df_songs.groupby(['artist_name'])['listen_count'].count().reset_index().sort_values(['listen_count', 'artist_name'], 
                                                                                                ascending = [0,1])

# %%
ten_pop_artists = ten_pop_artists[:10]
ten_pop_artists
plt.figure()
labels = ten_pop_artists['artist_name'].tolist()
counts = ten_pop_artists['listen_count'].tolist()
sns.barplot(x=counts, y=labels, palette='Set2')
sns.despine(left=True, bottom=True)

# %%
listen_counts = pd.DataFrame(df_songs.groupby('listen_count').size(), columns=['count'])
print(f"The maximum time the same user listened to the same songs was: {listen_counts.reset_index(drop=False)['listen_count'].iloc[-1]}")
print(f"On average, a user listen to the same song {df_songs['listen_count'].mean()} times")
# Out:
# The maximum time the same user listened to the same songs was: 2213
# On average, a user listen to the same song 3.0454845 times

# %%
listen_counts_temp = listen_counts[listen_counts['count'] > 50].reset_index(drop=False)

# %%
plt.figure(figsize=(16, 8))
sns.barplot(x='listen_count', y='count', palette='Set3', data=listen_counts_temp)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show();

# %%
song_user = df_songs.groupby('user_id')['song_id'].count()

# %%
plt.figure(figsize=(16, 8))
sns.distplot(song_user.values, color='orange')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show();

# %%
print(f"A user listens to an average of {np.mean(song_user)} songs")
print(f"A user listens to an average of {np.median(song_user)} songs, with minimum {np.min(song_user)} and maximum {np.max(song_user)} songs")
# Out:
# A user listens to an average of 26.194124657839247 songs
# A user listens to an average of 16.0 songs, with minimum 1 and maximum 711 songs

# %%
# Get how many values should it be if all songs have been listen by all users
values_matrix = unique_users * unique_songs
# Substract the total values with the actural shape of the DataFrame songs
zero_values_matrix = values_matrix - df_songs.shape[0]
print(f"The matrix of users x songs has {zero_values_matrix} values that are zero")
# Out:
# The matrix of users x songs has 728469151 values that are zero

# %% [markdown]
# Preparing the data

# %%
# Get users which have listen to at least 16 songs
song_ten_id = song_user[song_user > 16].index.to_list()
# Filtered the dataset to keep only those users with more than 16 listened
df_song_id_more_ten = df_songs[df_songs['user_id'].isin(song_ten_id)].reset_index(drop=True)

# %%
df_song_id_more_ten
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1635297  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJEYPO12AAA8C6B0E
# 1635298  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJJYDE12AF729FC16
# 1635299  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJKQSF12A6D4F5EE9
# 1635300  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJUXGA12AC961885C
# 1635301  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJYOLS12A8C13C06F
#
#          listen_count                           title  \
# 0                   1                        The Cove
# 1                   2                 Entre Dos Aguas
# 2                   1                        Stronger
# 3                   1                  Constellations
# 4                   1                    Learn To Fly
# ...               ...                             ...
# 1635297             2       Ignorance (Album Version)
# 1635298             4          Two Is Better Than One
# 1635299             3  What I've Done (Album Version)
# 1635300             1                              Up
# 1635301             1      Soil_ Soil (Album Version)
#
#                                release  \
# 0                   Thicker Than Water
# 1                  Flamenco Para Niños
# 2                           Graduation
# 3                    In Between Dreams
# 4        There Is Nothing Left To Lose
# ...                                ...
# 1635297                      Ignorance
# 1635298                     Love Drunk
# 1635299                 What I've Done
# 1635300                      My Worlds
# 1635301                        The Con
#
#                                     artist_name  year
# 0                                  Jack Johnson     0
# 1                                 Paco De Lucia  1976
# 2                                    Kanye West  2007
# 3                                  Jack Johnson  2005
# 4                                  Foo Fighters  1999
# ...                                         ...   ...
# 1635297                                Paramore     0
# 1635298  Boys Like Girls featuring Taylor Swift  2009
# 1635299                             Linkin Park  2007
# 1635300                           Justin Bieber  2010
# 1635301                          Tegan And Sara  2007
#
# [1635302 rows x 7 columns]

# %%
# convert the dataframe into a pivot table
df_songs_features = df_song_id_more_ten.pivot(index='song_id', columns='user_id', values='listen_count').fillna(0)

# obtain a sparse matrix
mat_songs_features = csr_matrix(df_songs_features.values)

# %%
type(mat_songs_features)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
res = df_songs_features

# %%
res = res.iloc[:100,:100]

# %%
res
# Out:
# user_id             000e2c2a8c7870ff9121f212b35c8b3a20cc0e67  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             000ebc858861aca26bac9b49f650ed424cf882fc  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             000ef25cc955ad5841c915d269432eea41f4a1a5  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             0012bf75d43a724f62dc746d9e85ae0088a3a1d6  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             001322829b5dc3edc59bf78189617ddd8f23c82a  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00185e316f07f0f00c325ca034be59c15b362401  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             0019740e3e8c24e223a6f88e3faa7c144ec5a014  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       1.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             001b005fe5e80d3cb45f320f5658fc8e2e72794e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             001f22c638730aed5659034c447d3cf0e658898e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             0021d9a4628624f6d70237f9c200ab82e766bf26  ...  \
# song_id                                                       ...
# SOAAAGQ12A8C1420C8                                       0.0  ...
# SOAACPJ12A81C21360                                       0.0  ...
# SOAACSG12AB018DC80                                       0.0  ...
# SOAAEJI12AB0188AB5                                       0.0  ...
# SOAAFAC12A67ADF7EB                                       0.0  ...
# ...                                                      ...  ...
# SOAFRIN12A81C22087                                       0.0  ...
# SOAFTFX12A6D4F3B78                                       0.0  ...
# SOAFTRR12AF72A8D4D                                       0.0  ...
# SOAFVWW12A58A7E1CB                                       0.0  ...
# SOAGFFD12AC909761F                                       0.0  ...
#
# user_id             00c20b0eaab9df260afd43c8291b6a304bf15b24  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00c58468e0393721a318b0815f34b01c0c55fa0a  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00c7057edc5395969f67d7302e3e39efb918e519  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00c896b9c9a55b1f3bf748aa8c5ef42924e752e4  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00c8da0ff833119515bfa60d7256c7ce8f1bf384  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00ca440ec4c11b839b63a3a917a606db81f60669  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00cc45c03614a0fdd0bcd957eaf4305ef3c43531  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00cd2733d4efb3a74385ef99559f59867d389178  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00cdffd2a5ba9705e6945cb3e53380ff2639268e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# user_id             00d711a6a558b4d8480e710c36aa52e266755a48
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# ...                                                      ...
# SOAFRIN12A81C22087                                       0.0
# SOAFTFX12A6D4F3B78                                       0.0
# SOAFTRR12AF72A8D4D                                       0.0
# SOAFVWW12A58A7E1CB                                       0.0
# SOAGFFD12AC909761F                                       0.0
#
# [100 rows x 100 columns]

# %%
res.to_csv("file3.csv")

# %%
df_unique_songs = df_songs.drop_duplicates(subset=['song_id']).reset_index(drop=True)[['song_id', 'title']]

# %%
decode_id_song = {
    song: i for i, song in 
    enumerate(list(df_unique_songs.set_index('song_id').loc[df_songs_features.index].title))
}

# %%
decode_id_song
# Out:
# {'Orgelblut': 0,
#  'Cearc Agus Coileach / The Hen And Cock': 1,
#  'I Gotta Feeling (Edit)': 2,
#  'Godlovesugly': 3,
#  "Rome Wasn't Built In A Day": 4,
#  'Jesus Loves You (Album Version)': 5,
#  'End Of The World Party': 6,
#  'So Confused (feat. Butta Creame) (amended album version)': 7,
#  'Stay Awhile': 8,
#  'Nomenclature': 9,
#  'Criminal': 7225,
#  'Juke Box Hero (Remastered LP Version )': 11,
#  'Aunt Eggma Blowtorch': 12,
#  'Radio': 13,
#  "Love Don't Live Here Anymore": 14,
#  'My Shepherd (Psalms 23) (featuring Kurt Carr & Avalon)': 15,
#  'STARSTRUKK [FEATURINGKATYPERRY] (Explicit Bonus Version)': 16,
#  'Hallelujah (Album Version)': 17,
#  'Brand New Day': 5415,
#  'Psycho': 19,
#  'Shadow Of The Day (Album Version)': 20,
#  'Back Against The Wall': 21,
#  'Halo': 52,
#  'Mass Appeal (Explicit)': 23,
#  'The Canals Of Our City': 24,
#  'Public Service Announcement (Interlude)': 25,
#  'The Drying of the Lawns': 26,
#  "You'll Never Know (Live Version)": 27,
#  "Who's That Girl (Soundtrack Album Version)": 28,
#  'A Pain That I\x19m Used To': 29,
#  'Oh Very Young': 30,
#  'Moan': 5265,
#  '221': 32,
#  "Player's Anthem feat. Notorious B.I.G._ Lil\x19 Cease and Lil\x19 Kim": 33,
#  "I'm Bad": 34,
#  'These Stones Will Shout': 35,
#  'I Hate Everything About You': 36,
#  'Work It Out': 7060,
#  'Legacy Of Kings': 38,
#  "You're Gonna Miss Me When I'm Gone": 39,
#  'Full Circle': 40,
#  'Burn Clear': 41,
#  'On A Deeper Level': 42,
#  'William_ It Was Really Nothing': 43,
#  'Combat Rock': 44,
#  'Speed': 6981,
#  'Surprise Ice': 46,
#  'Rock The House (Radio Edit)': 47,
#  'All I Want Is You (Josh Harris Remix)': 48,
#  'All The Way (Single Version)': 49,
#  'Talk Show Host': 50,
#  'If I Ever Fall In Love': 51,
#  'La Nina': 53,
#  'Falling': 922,
#  'Union House Branch': 55,
#  "Champagne's For Celebrating (I'll Have A Martini) (Album)": 56,
#  'Ray Of Light (Album Version)': 57,
#  'Always Where I Need To Be': 58,
#  'Roam [Edit]': 59,
#  'Heroína': 60,
#  'Dumb Blood': 61,
#  'You And Me Jesus': 62,
#  'Luno': 63,
#  'Until The Morning': 64,
#  'You Got Lucky': 65,
#  'Deireadh An Tuath': 66,
#  'The Ecstasy Of Gold': 67,
#  'Graveyard Girl': 68,
#  "I Can't Decide": 69,
#  'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)': 70,
#  'Victim Of The Crime': 71,
#  'Michael': 3291,
#  'Trátame Suavemente': 73,
#  'Free Love': 74,
#  'Words': 75,
#  'Parasito': 76,
#  'Toxic': 8099,
#  'Chattahoochee': 78,
#  'Go Places': 79,
#  "Just Couldn't Tie Me Down": 80,
#  'Nada Es Para Siempre': 81,
#  'Wasting My Time (Album Version)': 82,
#  'Highway 20 Ride (Album)': 83,
#  'Hollywood Whore': 84,
#  'Panty Droppa [Intro] (Album Version)': 85,
#  'Voodoo': 86,
#  'Iconography': 87,
#  'The Queen of Nothing': 88,
#  "Natural's Not In It": 89,
#  'See Saw': 90,
#  'Something': 9282,
#  'Caroline': 5866,
#  "I'm Still Breathing": 93,
#  'Bust A Move': 94,
#  'Walzer Nr. 7 op. 64_2 Cis-Moll': 95,
#  'Prelude/Prologue': 96,
#  'Harder Better Faster Stronger': 97,
#  'Headlong': 98,
#  'Keep It Clean': 99,
#  'Empire Ants (Feat. Little Dragon)': 100,
#  'Ready to Flow 2008': 101,
#  'Run Me Down': 102,
#  "I'll Be There For You": 103,
#  "I'd Love To Change The World (1998 Digital Remaster)": 104,
#  'Life On Mars?': 105,
#  "It's Been Awhile (Clean Edit)": 106,
#  'Positive Tension': 107,
#  'Heartbreaker/"If You Should Ever Be Lonely': 108,
#  'Time Bomb': 109,
#  'Cancer': 110,
#  'Surrounded': 111,
#  'Money Folder': 112,
#  'Floating Vibes': 113,
#  "Adam's Song": 114,
#  'True love': 115,
#  'Anoche Soñé Contigo': 116,
#  'A Thousand Miles': 117,
#  'Bad Moon Rising': 118,
#  'Shiver': 7399,
#  'Amor Prohibido': 120,
#  'The Webs We Weave': 121,
#  'Phantom Part 1.5 (Album Version)': 122,
#  'Midnight Souls Still Remain': 123,
#  'Hannibal': 124,
#  'Bad Girlfriend [Explicit]': 125,
#  'Corazon Espinado': 126,
#  'The Rat (Album Version)': 127,
#  'Jam 292': 128,
#  "Children's Story": 129,
#  'Liebeslied (Sprachen: Deutsch_ Englisch_ Französisch_ Italienisch_ Spanisch_ Holländisch_ Japanisch_ Russisch_ Griechisch_ Klingonisch_ Hessisch)': 130,
#  'The Outsider': 131,
#  'Blind Date': 132,
#  'Iko Iko': 133,
#  'My Moon My Man': 134,
#  'Simarik': 135,
#  'O My God': 136,
#  'Bachelorette (Family Tree Version)': 137,
#  'Sexual Eruption': 138,
#  'I Got Mine': 139,
#  'Keep It Loose_ Keep It Tight': 140,
#  'Good Love Is On The Way': 141,
#  'Courtesy Laughs': 142,
#  'Condemn Me Society (Katadikase me koinonia)': 143,
#  'When It Rains (Album Version)': 144,
#  'Fader': 145,
#  'Dirty Dishes': 146,
#  'The Perfect Kiss': 147,
#  'See You Soon': 148,
#  'Face To Face (Cosmo VItelli Remix)': 149,
#  "Tant Que L'on S'aimera": 150,
#  'Poor Jackie': 151,
#  "School's Out": 152,
#  'The Cove': 153,
#  'Such Great Heights': 154,
#  'Horseshoes And Handgrenades (Album Version)': 155,
#  'Como Brillaba tu Alma': 156,
#  'High School Musical': 157,
#  'Lo  Que Tengo Yo Adentro': 158,
#  "Walk-Don't Run": 159,
#  'Clouds (Of Color Bright Album Version)': 160,
#  'The Shark': 161,
#  'All We Are': 503,
#  'Song For You': 163,
#  'Summer In Dixie (LP Version)': 164,
#  "Stop Me If You Think You've Heard This One Before": 165,
#  'Loverboy': 166,
#  'Jumping Jack Flash': 167,
#  'Been A Son': 168,
#  'Marquee Moon (LP Version)': 169,
#  'Hey (Album Version)': 170,
#  'James': 171,
#  'Killa': 172,
#  'Just': 173,
#  'Move Along': 174,
#  "I'm Only Me When I'm With You": 175,
#  'Sail To The Moon': 176,
#  'Be My Baby': 177,
#  'Always Coming Back Home To You': 178,
#  'Perfecta': 179,
#  'Bad Sneakers': 180,
#  'Put Your Head On My Shoulder (Album Version)': 181,
#  'Soldier On': 182,
#  'When the empire falls (Single Version)': 183,
#  'How Can You Mend A Broken Heart?': 184,
#  "When Your Mind's Made Up (Album version)": 185,
#  'One Man Show': 186,
#  "Who's Your Daddy? ": 187,
#  "Little Miss Can't Be Wrong": 188,
#  'Pogo': 189,
#  'Lonely': 190,
#  'Cannonball': 1095,
#  'Fireworks': 8251,
#  'Wake Up': 4373,
#  "Don't Cry (Original)": 194,
#  'Nokian Takana': 195,
#  'Alguien Soy Yo': 196,
#  "Toca's Miracle": 7086,
#  'Rorol': 198,
#  'Girl With One Eye (Bayou Percussion Version)': 199,
#  'Curs in the Weeds': 200,
#  'This Bitter Pill': 201,
#  'Come With Me': 202,
#  'Cat People (Putting Out Fire)': 203,
#  'Bang Bang': 7320,
#  'Skills To Pay The Bills': 205,
#  "Mal D'Africa (2004 Digital Remaster)": 206,
#  'Cold Blooded (Acid Cleanse)': 207,
#  'Uprising': 208,
#  'No One Else': 209,
#  'Piggy': 210,
#  'Step Through The Door': 211,
#  'The Modern Age': 212,
#  'Knocking On Forbidden Doors': 213,
#  "It's Just A Thought": 214,
#  'Tchaparian': 215,
#  'In': 216,
#  'Sleep All Day (LP Version)': 217,
#  'False Pretense': 218,
#  'Echoes': 219,
#  'Sometimes Things Get_ Whatever': 220,
#  'Would You Please': 221,
#  'Let It Go': 222,
#  'Lonelily': 223,
#  'Not For You': 224,
#  "What Was I Thinkin'": 225,
#  'Your Visits Are Getting Shorter': 226,
#  'Burial': 227,
#  'Bullet Tells The Truth': 228,
#  'Everything In Its Right Place': 229,
#  'Mad Season (LP Version)': 230,
#  'Overload': 231,
#  'Medicating': 232,
#  "Can't Smile Without You": 233,
#  'Corrido de Boxeo': 234,
#  'With Arms Outstretched (Album Version)': 235,
#  'Mein Herz Brennt': 236,
#  'Me Quedo Contigo [Si Me Das A Elegir]': 237,
#  'TE QUIERO PUTA!': 238,
#  'Bittersweet': 239,
#  'Barely Breathing (LP Version)': 240,
#  'Raise Up': 241,
#  "I'm Your Boogie Man": 242,
#  'The Good Fight': 243,
#  'Angel De Orión': 244,
#  'Crazy For This Girl': 245,
#  '100°': 246,
#  'Get Innocuous! (Soulwax Remix)': 247,
#  'Auto-Dub': 248,
#  'Miami': 249,
#  'Kilometros': 250,
#  'This Joint': 251,
#  'Lemme Get That': 252,
#  'Introduction To Falling (Fragment)': 253,
#  'Lentil': 254,
#  'Sin Documentos': 255,
#  'Common Pleasure [Eagles Ballroom Live Version]': 256,
#  'The Bitter End': 257,
#  'Cassie': 258,
#  'Chump (Album Version)': 259,
#  'Take A Chance On Me': 2404,
#  'Celestica': 261,
#  "I'd Hate To Be You When People Find Out What This Song Is About (Album)": 262,
#  'Black Cherry': 263,
#  'You And Me (Wedding Version)': 264,
#  'Runaway': 1880,
#  'Playground': 266,
#  'That Was Just A Dream': 267,
#  "Fallin' Out": 268,
#  'Smile': 269,
#  'Face To Face (Demon Remix)': 270,
#  'Amerika': 271,
#  'Jimi Thing': 272,
#  'Ever Dream': 273,
#  'Por quererte': 274,
#  'Nocturnal': 275,
#  'Up Up & Away': 276,
#  'Mistress Mabel': 277,
#  'Hemma Före Mörkret': 278,
#  "Don't Stop...Planet Rock (In The Pocket Mix) feat. Bambaataa_ Eric Kupper & Mohamed Moretta": 279,
#  'Bitch Please (Explicit) (Feat. Xzibit)': 280,
#  'Eton Boating Song/Wyoming Lullaby/The Wiffenpoof Song (Baa Baa Baa) (Medley)': 281,
#  'Automobile (Feat. Eazy-E)': 282,
#  'Move On Up (Extended LP Version)': 283,
#  'Charly (Trip Into Drum And Bass Version) (Remastered)': 284,
#  'Long As I Can See The Light': 285,
#  'Recess': 286,
#  'The Dirty Glass': 287,
#  'Five Minutes To Midnight': 288,
#  'Welk': 289,
#  'Hello Good Morning': 290,
#  'O Hosanna': 291,
#  'Beautiful_ Dirty_ Rich': 292,
#  "Cheers Darlin'": 293,
#  "Demon's Gate": 294,
#  'Mutt': 295,
#  'Paradise Circus': 296,
#  'Sensible Heart': 297,
#  'Take Me To The Riot': 298,
#  'Aerodynamic': 299,
#  'Wait For The Summer': 300,
#  'Shoulder Holster': 301,
#  'The Metal': 302,
#  "The Zookeeper's Boy": 303,
#  'Do The Rump': 304,
#  'Swallowed In The Sea': 305,
#  'Side Effects': 306,
#  'Brother': 6690,
#  'Molossus': 308,
#  "Can't Fight The Moonlight (Theme From 'Coyote Ugly')": 309,
#  'Seven Nation Army': 310,
#  'Marble House': 2247,
#  'Rollerblades': 312,
#  "Until You're Over Me": 313,
#  'The Prize': 314,
#  'Frente A Frente': 315,
#  'The Blue Notebooks': 316,
#  'Undo': 317,
#  'Hilarious Movie Of The 90s': 318,
#  'King For A Day (Album Version)': 319,
#  'Les derniers aventuriers': 320,
#  'Smart Bomb': 321,
#  'Hail To Whatever You Found In The Sunlight That Surrounds You': 322,
#  'Meet the Monster': 323,
#  "Now I'm High_ Really High": 324,
#  'Nut City (2000 Digital Remaster) (The Rudy Van Gelder Edition)': 325,
#  'Hot N Cold (Manhattan Clique Remix Radio Edit)': 326,
#  "Rockin' Around The Christmas Tree": 327,
#  'Plasticities': 328,
#  'Not To Touch The Earth [Take 2]': 329,
#  'Second Heartbeat': 330,
#  'Fins': 331,
#  'Kiwi': 332,
#  'Walk In The Park': 333,
#  'Losing Touch': 334,
#  'Do You Really Want To Hurt Me': 335,
#  'Welcome Home (Sanitarium)': 336,
#  'I Wonder': 337,
#  'Diary': 338,
#  'Noise': 339,
#  'Make Gay Love Not War': 340,
#  'Lie To Me': 341,
#  "One More Time (Romanthony's Unplugged)": 342,
#  'No More Tears': 343,
#  "Don't Haunt This Place": 344,
#  'Crossing Over': 345,
#  'Lemonade': 346,
#  'Beautiful Disaster': 347,
#  'Dirty Movies" (Album Version)': 348,
#  'Olio': 349,
#  'Through The Hosiery': 350,
#  'Kid A': 351,
#  'Dog Days Are Over (Radio Edit)': 352,
#  'Over The Rainbow': 9290,
#  'The Electric Version': 354,
#  'Misery Business (Single Version)': 355,
#  'Amor de Loca Juventud': 356,
#  'Littlest Things': 357,
#  'Echo Sam': 358,
#  'La Tablada': 359,
#  "We Ain't": 360,
#  "This Ain't A Love Song": 2598,
#  "Breakfast At Tiffany's": 362,
#  "You're The Voice": 363,
#  'Grace Kelly': 364,
#  'Like A Rolling Stone': 4996,
#  'Family Tree': 366,
#  "Flora's Secret": 367,
#  'Dear Friend (The Secret Of Time Album Version)': 368,
#  'Erotic City ( LP Version)': 369,
#  'Magic Bus': 370,
#  'All Night': 371,
#  'All At Once': 4550,
#  'Souverian': 373,
#  'Mercedes Benz - Remix': 374,
#  'Buffalo Stance': 375,
#  'She Follows Her Own Rules (2007 Digital Remaster)': 376,
#  'Catch Me': 377,
#  'Santa Monica': 378,
#  'Open All Night': 379,
#  'Baby Did A Bad Bad Thing (LP Version)': 380,
#  'La chica banda': 381,
#  'Elenore': 382,
#  'I Was Made For You': 383,
#  'Six Days': 384,
#  'On Green Dolphin Street (Medley) (1999 Digital Remaster)': 385,
#  'Call Me If You Need Me': 386,
#  "She's My Baby (2007 Remastered LP Version)": 387,
#  'Matchbox': 388,
#  "Don't Get Lost In Heaven": 389,
#  'Oceanside': 390,
#  'Rhineland (Heartland)': 391,
#  'Soñe Otro Mundo': 392,
#  'Nah!': 393,
#  'The Saltwater Room': 394,
#  'Deliverance': 395,
#  'Imma Be': 396,
#  "If You're Not The One": 397,
#  'Planet 7': 398,
#  'All Along The Watchtower': 9927,
#  'Frontline': 400,
#  'Hear You Me': 401,
#  'Sunday Bloody Sunday': 402,
#  'Greenback Dollar': 758,
#  'Here It Goes Again': 404,
#  'Murderers (Album Version)': 405,
#  'At The Beach': 406,
#  'Brothers': 407,
#  'A Girl Like You': 2239,
#  'Respect': 409,
#  'More Adventurous (Album Version)': 410,
#  'At The Bottom Of Everything': 411,
#  'Where Is My Mind?': 412,
#  'Entre Dos Aguas': 413,
#  'Manowar': 414,
#  "I'm Not Jesus": 415,
#  'Melancholy Mood': 416,
#  'Woods': 417,
#  'Mary (Album)': 418,
#  'The Worm': 419,
#  "Ain't It Fun": 420,
#  'The Scale': 421,
#  'Pop Is Dead': 422,
#  'No One': 2492,
#  'Pero Me Acuerdo De Tí': 424,
#  'Forever My Friend': 425,
#  'Move Shake Drop Remix': 426,
#  'Blue (Da Ba Dee)': 427,
#  "Walkin' On The Sun": 428,
#  'Only You': 8928,
#  'I Want You To Want Me': 430,
#  'Humming': 431,
#  'Mammoth': 432,
#  'El Chico Del Apartamento 512': 433,
#  'Street Corner Preacher': 434,
#  'My Savior My God (Album Version)': 435,
#  'Chi Mai (El Profesional)': 436,
#  'I Miss You': 3032,
#  'We Belong': 438,
#  "Don't Dink and Drance (Album Version)": 439,
#  'Making Time': 440,
#  'Thong Song': 441,
#  'Here We Are (Family In The Hallways)': 442,
#  'You Know What You Are?': 443,
#  'Indo Silver Club': 444,
#  'Younger Than Springtime': 445,
#  'Sun Hands': 446,
#  'Daisy And Prudence': 447,
#  'Steam Machine': 448,
#  'Just Like You (Karaoke)': 449,
#  'Love': 765,
#  "Don't Bring Me Down": 451,
#  'Forget Myself (2006 Remastered Version)': 452,
#  'Ghost': 2490,
#  'Rumour (Abstract Hip Hop Mix)': 454,
#  'Forever Loving Jah': 455,
#  'You Had Me At Hello': 456,
#  'This Cowboy Song': 457,
#  'I.nner Indulgence': 458,
#  'Signal Fire': 459,
#  'Desafinado': 460,
#  'Unstoppable': 461,
#  'Baby Boy [feat. Beyonce]': 462,
#  'Black Man Ray': 463,
#  'FM': 464,
#  'Let Me Fall (From Cirque du Soleil) (Album Version)': 465,
#  'Murder She Wrote': 466,
#  'High Life': 467,
#  'A Message To You Rudy': 468,
#  'Bulgarian  Chicks': 469,
#  'When You Love A Woman': 470,
#  'Crystal Blue Persuasion': 471,
#  'Stranger': 472,
#  'Le Courage Des Oiseaux': 473,
#  'Remember (Walking In The Sand)': 474,
#  'Australia': 475,
#  'Face Plant (LP Version)': 476,
#  'I Ran Away': 477,
#  'Dream A Little Dream Of Me': 478,
#  "These Boots are Made For Walkin' (2006 Digital Remaster)": 479,
#  "Don't Forget About Us": 480,
#  "I Don't Wanna Walk Around With You  (Remastered Album Version )": 481,
#  'Hayling': 482,
#  'Olympic Airways': 483,
#  'Everythings Just Wonderful': 484,
#  'Waiting For A Girl Like You': 485,
#  'Friction': 486,
#  'Take It In': 487,
#  'Música Para Una Boda': 488,
#  'Love Comes Tumbling': 489,
#  "There's A War Going On For Your Mind": 490,
#  'Merry Happy / Little Red': 491,
#  'The Alliance Of Hellhoundz': 493,
#  'Jeremy': 494,
#  'Constant Knot': 495,
#  'Paperthin Hymn': 496,
#  'Odd One (Radio Edit)': 497,
#  'Buddy Holly': 498,
#  'Black & Blue': 6657,
#  'Anonymous': 4003,
#  'Perderte De Nuevo': 501,
#  'Keep Your Hands To Yourself (LP Version)': 502,
#  'Crepuscule With Nellie': 504,
#  'Miss Sarajevo': 505,
#  "Ex's And Oh's (LP Version)": 506,
#  'Primer Dia': 507,
#  'All I Need': 7237,
#  'The Wicked End (Album Version)': 509,
#  'Lovely Head': 510,
#  "Cryin' Blues": 511,
#  'The Ballad of Michael Valentine': 512,
#  'Come To Me': 6303,
#  'Roscoe': 514,
#  'As Good As I Once Was': 515,
#  'D.A.N.C.E. [Radio Edit]': 516,
#  'Overrated': 517,
#  'California One / Youth and Beauty Brigade': 518,
#  'Invincible': 8573,
#  'Boadicea': 520,
#  'When The Lights Go Out': 521,
#  "We're Looking For A Lot Of Love": 522,
#  'Charmer': 523,
#  'Long Black Road': 524,
#  'Cathedral   (LP Version)': 525,
#  'Woman In Chains': 526,
#  'Tough Little Boys': 527,
#  'Emotion': 528,
#  'Hot Boyz (w/ Dear Nora)': 529,
#  'Ugly': 530,
#  'In and Out of Love': 531,
#  'Cupid': 3711,
#  "I'd Rather Be With You": 533,
#  'Wonderwall': 534,
#  'Respira': 535,
#  'Safe From Harm': 536,
#  'Two Hearts': 537,
#  'Just A Man': 538,
#  "There's A Good Reason These Tables Are Numbered Honey_ You Just Haven't Thought of It Yet [Live In Chicago]": 539,
#  'Also Frightened': 540,
#  'Waimea Bay': 541,
#  'Sweet Dreams': 7114,
#  'X-Static': 543,
#  'Be Less Rude': 544,
#  'So Lonely': 545,
#  'Missing Persons 1 & 2': 546,
#  'Hold On': 8390,
#  "Let's Make Love And Listen To Death From Above [Dan Carey Mix] (remastered album version)": 548,
#  'I Stand Corrected (Album)': 549,
#  'Jolene [Live]': 550,
#  'What New York Couples Fight About (Feat: Kurt Wagner)': 551,
#  'Night Drive (Acoustic)': 552,
#  'Sweet And Low': 553,
#  'I Wish Today Could Be Tomorrow': 554,
#  'Lullaby': 7334,
#  'All My Friends': 9055,
#  'Anything But Ordinary': 557,
#  'Rewind [feat. Wyclef Jean] (Album Version)': 558,
#  'Napoleon On The Bellerophon': 559,
#  'Purple Weed': 560,
#  'Going For the Gold': 561,
#  'Implosion of Eternity': 562,
#  'The Flowers (Album Version)': 563,
#  'Harder Better Faster Stronger (Alive Radio Edit 2007)': 564,
#  'Hints': 9018,
#  'Runaway ( LP Version )': 566,
#  'Are We The Waiting [feat. Green Day & The Cast Of American Idiot] (Album Version)': 567,
#  'Epona': 568,
#  'All My Mistakes (US4BW0700133)': 569,
#  "My Lovin' (You're Never Gonna Get It) (LP Version)": 570,
#  'New Orleans (Album Version)': 571,
#  'Move On': 572,
#  'Nine Times Out Of Ten (1998 Digital Remaster)': 573,
#  'How Come': 4142,
#  'Infected': 575,
#  'Cathar Rhythm': 576,
#  'Steps Of Faith': 577,
#  'Slip': 578,
#  'Winter Song': 579,
#  'Prince Caspian': 580,
#  'Las flores': 581,
#  'Faces In The Hall': 582,
#  'Must Be Dreaming': 583,
#  'No. 5': 584,
#  'Mykel And Carli': 585,
#  'Sacred Lie (Album Version)': 586,
#  'Nightlite (Zero dB Reconstruction - Radio Edit)': 587,
#  'En El Cielo No Hay Cerveza (In Heaven There Is No Beer)': 588,
#  'Kiss Me Thru The Phone': 589,
#  'Sitting On The Curb (LP Version)': 590,
#  'Keep The Car Running': 591,
#  "I'm Yours (Album Version)": 592,
#  'East Northumberland High': 593,
#  'Length Of Love': 594,
#  'Can You Tell': 595,
#  'Parks': 596,
#  'Chattanooga Choo Choo (2004 Digital Remaster)': 597,
#  'Stay': 598,
#  'Symbol In My Driveway': 599,
#  'Back To School (Mini Maggit) (LP Version)': 600,
#  'Find The Cost Of Freedom': 601,
#  'Heart And Soul': 602,
#  "Lady Dada's Nightmare": 603,
#  'The Execution Of All Things (Single Version)': 604,
#  'Lucky (Album Version)': 605,
#  'Queer': 606,
#  'Man Who Make You Sick': 607,
#  'The Girl And The Robot': 608,
#  'Solid Gone': 609,
#  'Keep Your Hands Off Her': 610,
#  'Korg Rhythm Afro': 611,
#  "I Don't Want To Be": 612,
#  'Rapture at Sea': 613,
#  "You're The One": 5962,
#  'Die_ All Right!': 615,
#  'Kelma': 616,
#  'Sincerité Et Jalousie': 617,
#  'Tell Him The Truth': 618,
#  'Possible Grenade': 619,
#  'The Hardest Button To Button': 620,
#  'Questo Pazzo Pazzo Mondo Di Tasse': 621,
#  'Don´t Leave Me Now': 622,
#  'Kitty': 623,
#  'Invitation To Understanding': 624,
#  'This Fire': 625,
#  'Teardrop': 8858,
#  'Sinners Like Me': 627,
#  'Higher Than The Sun': 628,
#  'Rusted Wheel': 629,
#  "'Till I Collapse": 630,
#  'Flat Beat': 631,
#  'Down And Out (Album Version)': 632,
#  'Walk A Little Straighter': 633,
#  'The Outer Banks': 634,
#  'Decades Of Despair': 635,
#  'Could It Be You (punk Rock Chick)': 636,
#  'Veleta (En Vivo Auditorio Nacional)': 637,
#  "J'ai Dormi Sous L'eau": 638,
#  'Flowers On The Wall': 639,
#  "I'm A Little Rocket Ship": 640,
#  'Men Who Love Women Who Love Men': 641,
#  'The Least You Can Do': 642,
#  'Father Of Mine': 643,
#  'Alice Practise': 644,
#  'The Unwinding Cable Car': 645,
#  'Pretty Little Ditty': 646,
#  'Bag Lady': 647,
#  'Strength': 648,
#  'My Mom': 649,
#  'Cooler Than Me': 650,
#  'My Own Hell': 651,
#  'Charlotte Sometimes': 652,
#  'Heroes Get Remembered_ Legends Never Die': 653,
#  'How Can I Keep From Singing?': 654,
#  'El Novio Del Olvido': 655,
#  'Wherever You Will Go': 656,
#  'Luvstruck': 657,
#  'Bottom of a Bottle (Explicit Album Version)': 658,
#  'Rock & Roll Queen': 659,
#  'Adrift & At Peace': 660,
#  'Castles In The Sky': 661,
#  'Kingdom For A Heart': 662,
#  'Colgando en tus manos (con Marta Sanchez)': 663,
#  'White Light': 664,
#  'Amanda': 665,
#  'Orion': 666,
#  'Do-Wah-Doo': 667,
#  'Signals Over The Air': 668,
#  'A Stranger': 669,
#  'Cruel Summer': 670,
#  'Sad Songs (Say So Much)': 671,
#  'Geek In The Pink [Phil Tan Remix]': 672,
#  'Not Miserable': 673,
#  'Island In The Sun': 674,
#  'Elegante': 675,
#  "Don't Play That Song (You Lied) (LP Version)": 676,
#  'Either Way': 677,
#  'Hate It Or Love It': 678,
#  'Go Go Girls': 679,
#  'Happy': 680,
#  'Requiem For A Dying Song': 681,
#  "I Won't See You Tonight Part 1": 682,
#  'Willing To Wait': 683,
#  'Back Home (Album Version)': 684,
#  'What A Shame (Album Version)': 685,
#  'Get It Together': 686,
#  'By The Time I Get To Arizona': 687,
#  'Always Something There To Remind Me': 688,
#  "The Warrior's Code": 689,
#  "You Don't Have A Clue": 690,
#  'So Long-Guthrie': 691,
#  'Swimmers': 692,
#  'Us V Them': 693,
#  'One Of These Things First': 694,
#  'Normal Guy': 695,
#  'Heartbreaker': 7726,
#  'Where Did You Sleep Last Night': 697,
#  'Stranger than Fiction': 698,
#  'Crazy Little Thing Called Love (Album Version)': 699,
#  'Wish You Were Here': 1742,
#  'Parallel Lines': 701,
#  'Headknocker': 702,
#  'They Might Follow You': 703,
#  "Won't Go Quietly": 704,
#  'Hoisting The Flag': 705,
#  'Nitro (Youth Energy)': 706,
#  'War': 8807,
#  'The Killing Moon': 708,
#  'Immolate Yourself': 709,
#  'A Forest': 710,
#  'Teenage Kicks': 711,
#  'Not Alone Any More': 712,
#  'Intuition': 713,
#  'Red October': 714,
#  'Kinky Fætter': 715,
#  'Barfly': 716,
#  'Dance To The Music': 717,
#  "She Wouldn't Be Gone (Album Version)": 718,
#  'Monkey Man': 719,
#  'Primary': 720,
#  'Star Bodies': 721,
#  'Yo Tomo': 722,
#  'Is She Weird': 723,
#  'Primavera': 724,
#  'Here I Stand': 725,
#  'Funeral Song': 726,
#  "I Was Made For Lovin' You": 727,
#  'Orange Sky': 728,
#  'Remedy': 729,
#  'Mourning Dove': 730,
#  'Last Day Of Our Love': 731,
#  'Moje Mieszkanie': 732,
#  'Naturally': 733,
#  'Whores (2006 Remastered Album Version)': 734,
#  'Dirty Road': 735,
#  'Stronger': 6785,
#  'Adios': 6717,
#  'Elephant': 738,
#  "It's Still Rock And Roll To Me": 739,
#  'Wordplay (Album Version)': 740,
#  'Good Man': 741,
#  'Hey Shorty (Yeah Yeah Pt. II) (Feat. U$O & Johnson)': 742,
#  'Sweet Emotion': 743,
#  'Innocent Son': 744,
#  "If There's a Rocket Tie Me To It": 745,
#  'Owl Eyes': 746,
#  'Be Wild': 747,
#  'Where Do The Children Play?': 748,
#  'Lounge Fly (LP Version)': 749,
#  'Constellations': 750,
#  'Ikea': 751,
#  'Obsessions': 752,
#  'Break Through': 753,
#  'On The Run': 754,
#  'A La Mierda': 755,
#  'I Know What You Want': 756,
#  'Heavy Water': 757,
#  'Like The Sea': 759,
#  'Jolene': 760,
#  'People Got To Be Free': 761,
#  'Enterlude': 762,
#  'Head Over Heels': 763,
#  'Walking': 764,
#  "We're Going To Be Friends": 766,
#  'Bankrupt On Selling': 767,
#  'Meatplow (LP Version)': 768,
#  'Stay Lit': 769,
#  'Auto rojo': 770,
#  'Under The Gun': 771,
#  'Complicated': 772,
#  'Cocaine Habit': 773,
#  'Muérdete la lengua': 774,
#  'Accidntel Deth (Album Version)': 775,
#  'Every Morning': 776,
#  'Miss Murder': 777,
#  "For Me_ It's You": 778,
#  'The Story I Heard': 779,
#  "Don't Dream It's Over": 780,
#  'My Generation': 781,
#  'On Your Porch  (Album Version)': 782,
#  'Jesus_ Etc.': 783,
#  'When Will They Shoot? (Edited)': 784,
#  'Oh Timbaland': 785,
#  'TTHHEE PPAARRTTYY': 786,
#  'Act Too (Love Of My Life)': 787,
#  'S.O.S.': 788,
#  'Furious Rose': 789,
#  'In These Arms': 790,
#  'Lay Your Hands On Me': 791,
#  'Life Less Frightening': 792,
#  'How We Exit': 793,
#  'Youth Of The Nation (2006 Remastered Album Version)': 794,
#  'See The Sun': 1038,
#  'Hip-Hop Saved My Life (feat. Nikki Jean) (Explicit Album Version)': 796,
#  'Endless Love': 797,
#  'Love Theme': 798,
#  'Dragon Queen': 799,
#  'Northern Sky': 800,
#  'U.R.A Fever': 801,
#  'Tones Of Home': 802,
#  'Sleeping Sickness': 803,
#  'Love Is A Place': 804,
#  "We're An American Band (2002 Digital Remaster)": 805,
#  'Black Bird': 806,
#  'Born Too Slow': 807,
#  'I Was Meant For the Stage': 808,
#  "Don't Leave Me": 2603,
#  'We Have Love': 810,
#  'The Loneliness And The Scream': 811,
#  'Walk This Way': 812,
#  'Window In The Skies': 813,
#  'Teeth': 814,
#  'XRDS': 815,
#  'Today Your Love_ Tomorrow The World (Remastered Album Version )': 816,
#  'Hey': 8642,
#  'Dulce Compañia': 818,
#  "Don't Stand So Close To Me '86": 819,
#  'The Strength To Go On': 820,
#  'Apology': 821,
#  'Tonight (Featuring Mobb Deep & Joe Hooker)(Album Version)': 822,
#  'Corynorhinus': 823,
#  'Jump [feat. Nelly Furtado] (Album Version)': 824,
#  'Cath... (Album Version)': 825,
#  'Unholy Confessions': 826,
#  'Personal Jesus': 9299,
#  '5_ 6_ 7_ 8': 828,
#  'Forever & Always': 4995,
#  'Only One': 830,
#  'Song For No One': 831,
#  'Distance And Time': 832,
#  'LoveStoned/I Think She Knows': 5650,
#  'Vuelvo Al Sur': 834,
#  'Handlebars (UK Radio Edit)': 835,
#  'In Another Life (Album Version)': 836,
#  'Down Boy': 837,
#  'Mr. Jones (Explicit Version)': 838,
#  'Bottle Of Red Wine': 839,
#  'Jack & Diane': 840,
#  'Killing Me Softly With His Song': 841,
#  'End Of A Century': 842,
#  'This Song Is Called (Album Version)': 843,
#  'Shortie Like Mine': 844,
#  'Dark Moves Of Love': 845,
#  'Tied Together With A Smile': 846,
#  'Lazy Eye [Jason Bentley Remix]': 847,
#  'What Them Girls Like': 848,
#  'Miracle': 849,
#  'Freakum Dress': 850,
#  "She's A Lady": 851,
#  'One More Chance (Album Version)': 852,
#  'Resurrection': 853,
#  "Steady Mobbin' (Explicit)": 854,
#  'Mandarine Girl': 855,
#  'Pow Pow': 856,
#  'Hard To Explain': 857,
#  'Father Cannot Yell (Pete Shelley/Black Radio Mix)': 858,
#  'Stroke You Up (LP Version)': 859,
#  'Foundations': 860,
#  'Newjack': 861,
#  'Do U Wanna Ride': 862,
#  'Te Hacen Falta Vitaminas': 863,
#  'Attention': 864,
#  'Someday': 8937,
#  'Désolé': 866,
#  "It's No Good (Single Version)": 867,
#  'Detlef Schrempf (Album)': 868,
#  'Dollars & Cents': 869,
#  'The Wind Blows': 870,
#  'Swans': 871,
#  'Staralfur': 872,
#  'Wipe Out': 873,
#  'Ein Schiff Wird Kommen...': 874,
#  'I Can Change': 875,
#  'Astro Zombies': 876,
#  "I'm A Lady [feat. Trouble Andrew]": 877,
#  'Lothlórien': 878,
#  'Walking On A Dream': 879,
#  'Smoking Gun': 880,
#  'Christmas Time Is Here': 881,
#  'When We Dance': 882,
#  'Fake Tales Of San Francisco (Explicit)': 883,
#  'Bliss': 884,
#  'We Belong Together': 9590,
#  'Billy (Album Version)': 886,
#  'Yesterdays': 887,
#  'Spit It Out [Explicit]': 888,
#  "I'll Do Anything (LP Version)": 889,
#  'Tropicana': 890,
#  'Move The Crowd': 891,
#  'Bleeding Hearts': 892,
#  'Camera Talk': 893,
#  'Into The Groove': 894,
#  'El ciclón': 895,
#  'Neighborhood #3 (Power Out)': 896,
#  'Losing A Whole Year (2006 Remastered LP Version)': 897,
#  'White Meat': 898,
#  'Halfway There': 899,
#  'Team': 900,
#  'Mil Horas': 901,
#  'Rosa Pastel': 902,
#  'Full Circle (Explicit)': 903,
#  'Me_ Myself And I': 904,
#  'Die Kunst der Fuge_ BWV 1080 (2007 Digital Remaster): Contrapunctus XVII - Inversus': 905,
#  'Lost (Explicit Album Version)': 906,
#  "Let's Get It Started": 907,
#  'The Last Night (Album Version)': 908,
#  'Illumination': 7220,
#  "Don't Start Me Talkin'": 910,
#  'Para Tu Amor': 911,
#  'Girl Money': 912,
#  'Magic': 9705,
#  'Must Be The Ganja': 914,
#  'Not Fade Away': 915,
#  'Enter Sandman': 6793,
#  'End Of The Day': 917,
#  'My Night With the Prostitute From Marseille': 918,
#  'Where You From?': 919,
#  'Whoomp! There It Is': 920,
#  'Nutshell': 921,
#  'Melatonin': 923,
#  'Precious Things': 924,
#  'Hole In Your Head (bend in the road)': 925,
#  'One Minute To Midnight': 926,
#  'Come On Over (All I Want Is You)': 927,
#  'The Diary Of Jane (Acoustic)': 928,
#  'This Unfolds': 929,
#  "I'm Your Captain/Closer To Home (Medley) (2002 Digital Remaster)": 930,
#  'Tricky Tricky': 931,
#  'Ze Rook Naar Rozen': 932,
#  'Knee Deep At The National Pop League': 933,
#  'Guitar Man (LP Version)': 934,
#  'The Breaks': 935,
#  'Because You Loved Me': 936,
#  'Hallelujah': 7342,
#  'Leg 8': 938,
#  'Black Wave/Bad Vibrations': 939,
#  'Sensimillia': 940,
#  "It's Coming Down": 941,
#  'So Payaso (Version 2004)': 942,
#  'Wicked Garden (LP Version)': 943,
#  'By The Sword (featuring Andrew Stockdale or Wolfmother)': 944,
#  'Straight Outta Compton (Extended Mix) (Edit) (Explicit)': 945,
#  'Epic': 946,
#  'Amazing': 947,
#  'Never Ever': 1051,
#  'Burn': 8275,
#  'Disconnect_ Disconnect': 950,
#  'A Little Something': 951,
#  'Bleed It Out [Live At Milton Keynes]': 952,
#  'Lotion (LP Version)': 953,
#  'Sweetest Kill': 954,
#  'Shrooms': 955,
#  "I'll Hold My Breath": 956,
#  'Suspicious Minds': 957,
#  'Hippie Priest Bum-out (Edit)': 958,
#  'Accidental Babies': 959,
#  'Neighborhood #1 (Tunnels)': 960,
#  'Love In 2 Parts': 961,
#  'Point/Counterpoint (Album Version)': 962,
#  'Pam Berry (Album)': 963,
#  "You Can't Catch Me": 964,
#  'Tim McGraw': 965,
#  'Love (original)': 966,
#  'Life In Technicolor': 967,
#  'Heroes (Album Version)': 968,
#  'MMMBop': 969,
#  'Blood On The Ground': 970,
#  'The Chariot': 971,
#  'Keep Our Ring': 972,
#  'The Sweets': 973,
#  'Dreamlover': 3908,
#  'Duerme Conmigo': 975,
#  'I Will Be Grateful For This Day': 976,
#  'Queen Of The Rodeo': 977,
#  'Na Vi': 978,
#  'Captain America': 979,
#  'Heard Them Stirring': 980,
#  'Resurrection Fern (Album)': 981,
#  'Risingson': 982,
#  'Forgiven (Album Version)': 983,
#  'Coldest Winter': 984,
#  'Rhinestone Eyes': 985,
#  'Christmas Is My Favorite Time Of The Year': 986,
#  "Let's Fall In Love": 987,
#  'Mince Meat': 988,
#  'Angel From Montgomery': 989,
#  'Creil City': 990,
#  'Turbo Love': 991,
#  'Around The World (Motorbass Vice Mix)': 992,
#  'Lovefool': 993,
#  'Ona Kasuita': 994,
#  'Kept It Too Real (Amended Album Version)': 995,
#  "All Tomorrow's Parties": 996,
#  'Could We': 997,
#  "I'm On Fire": 998,
#  "Let's Dance To Joy Division (Full Length Version)": 999,
#  'Conspiracy (Album Version)': 1000,
#  'The Hand That Rocks The Cradle (+ Sonny Boy)': 1001,
#  'Bada': 1002,
#  'En El Septimo Dia': 1003,
#  'Mr Sandman': 1004,
#  'Exploration': 1005,
#  ...}

# %%
model = Recommender(metric='cosine', algorithm='brute',k=20, data=mat_songs_features, decode_id_song=decode_id_song)

# %%
model

# %%
song = 'I believe in miracles'

# %%
new_recommendations = model.make_recommendation(new_song=song, n_recommendations=10)
# Out:
# Starting the recommendation process for I believe in miracles ...
# ... Done

# %%
print(f"The recommendations for {song} are:")
print(f"{new_recommendations}")
# Out:
# The recommendations for I believe in miracles are:
# ['Nine Million Bicycles', 'If You Were A Sailboat', 'Shy Boy', 'I Cried For You', "Spider's Web", 'Piece By Piece', 'On The Road Again', 'Blues In The Night', 'Blue Shoes', 'Thank You Stars']

# %%
from collections import Counter
new_recommendations
# new_recomdation_2
a=list(new_recommendations)
c=list(new_recomdation_1['song'])
# a=new_recomdation_1['song']+new_recomdation_2['song']+new_recommendations
# a
b=list(new_recomdation_2['song'])
a=a+b+c
print(len(a))
a=Counter(a)
a
# Out:
# 30
# Counter({'Nine Million Bicycles': 1,
#          'If You Were A Sailboat': 1,
#          'Shy Boy': 1,
#          'I Cried For You': 1,
#          "Spider's Web": 1,
#          'Piece By Piece': 1,
#          'On The Road Again': 1,
#          'Blues In The Night': 1,
#          'Blue Shoes': 1,
#          'Thank You Stars': 1,
#          'Sehr kosmisch - Harmonia': 1,
#          'Undo - Björk': 1,
#          "You're The One - Dwight Yoakam": 1,
#          'Dog Days Are Over (Radio Edit) - Florence + The Machine': 1,
#          'Secrets - OneRepublic': 1,
#          'The Scientist - Coldplay': 1,
#          'Use Somebody - Kings Of Leon': 1,
#          'Revelry - Kings Of Leon': 1,
#          'Fireflies - Charttraxx Karaoke': 1,
#          'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner': 1,
#          'Oliver James - Fleet Foxes': 1,
#          'Quiet Houses - Fleet Foxes': 1,
#          'Your Protector - Fleet Foxes': 1,
#          'Tiger Mountain Peasant Song - Fleet Foxes': 1,
#          'Sun It Rises - Fleet Foxes': 1,
#          'The End - Pearl Jam': 1,
#          'St. Elsewhere - Dave Grusin': 1,
#          'Misled - Céline Dion': 1,
#          'Oil And Water - Incubus': 1,
#          'Meadowlarks - Fleet Foxes': 1})
